# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("pizza.csv")
# df
df.drop(columns=["remark"],inplace=True)
df.isna().sum()
df.dropna(inplace=True)
plt.pie(df["name"].value_counts().head().values,labels=df["name"].value_counts().head().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x180b2af9430>,
# ...
#  [Text(0.8841740928042875, 0.6543975654093734, 'classic_dlx'),
#   Text(-0.36185223242142994, 1.0387795540400415, 'bbq_ckn'),
#   Text(-1.0996508835594856, -0.027711627286080533, 'hawaiian'),
#   Text(-0.3129077297043408, -1.0545561875458678, 'pepperoni'),
#   Text(0.8980754271857303, -0.6351854273243114, 'thai_ckn')])

# %%
# df.drop(columns=["remark"],inplace=True)
# df

# %%
# df.isna().sum()
# df.dropna(inplace=True)

# %%
# import matplotlib.pyplot as plt
# plt.bar(df["time"].value_counts().index,df["time"].value_counts().values)
