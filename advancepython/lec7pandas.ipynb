# %%
import numpy as np
import pandas as pd

df=pd.read_csv('Course_info.csv')
df.shape
# Out:
# (209734, 20)

# %%
# df.head()#shows 5 values from top .csv file
df.tail()#shows 5 values from bottom .csv file
# Out:
#                id                                              title  is_paid  \
# 209729  4913954.0                Let's Speak Urdu - The Urdu Grammar     True
# 209730  4914146.0  CompTIA Linux+ (XKO-004/005 # 2 Practice Exam ...     True
# 209731  4914002.0  CISSP 4 full exams #1 : All CISSP domains - 12...     True
# 209732  4913934.0  JD Edwards EnterpriseOne Fixed Assets Accounti...     True
# 209733  4914054.0  CISSP 4 full exams #2 : All CISSP domains - 12...     True
#
#          price                                           headline  \
# 209729   19.99  Urdu - Become fluent in this beautiful South A...
# 209730   49.99  Practice Latest exam questions with detailed e...
# 209731   49.99  Practice Latest exam questions with detailed e...
# 209732  119.99  Full-length course (Part-3 of 3) on JD Edwards...
# 209733   49.99  Practice Latest exam questions with detailed e...
#
#         num_subscribers  avg_rating  num_reviews  num_comments  num_lectures  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209734 entries, 0 to 209733
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  209734 non-null  float64
#  1   title               209734 non-null  object
#  2   is_paid             209734 non-null  bool
#  3   price               209734 non-null  float64
#  4   headline            209703 non-null  object
#  5   num_subscribers     209734 non-null  float64
#  6   avg_rating          209734 non-null  float64
#  7   num_reviews         209734 non-null  float64
#  8   num_comments        209734 non-null  float64
#  9   num_lectures        209734 non-null  float64
#  10  content_length_min  209734 non-null  float64
#  11  published_time      209734 non-null  object
#  12  last_update_date    209597 non-null  object
#  13  category            209734 non-null  object
#  14  subcategory         209734 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# id                      0
# title                   0
# is_paid                 0
# price                   0
# headline               31
# num_subscribers         0
# avg_rating              0
# num_reviews             0
# num_comments            0
# num_lectures            0
# content_length_min      0
# published_time          0
# last_update_date      137
# category                0
# subcategory             0
# topic                 958
# language                0
# course_url              0
# instructor_name         5
# instructor_url        427
# dtype: int64

# %%
df["avg_rating"]=df["avg_rating"].astype("int")
df["avg_rating"].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['id', 'title', 'is_paid', 'price', 'headline', 'num_subscribers',
#        'avg_rating', 'num_reviews', 'num_comments', 'num_lectures',
#        'content_length_min', 'published_time', 'last_update_date', 'category',
#        'subcategory', 'topic', 'language', 'course_url', 'instructor_name',
#        'instructor_url'],
#       dtype='object')

# %%
for i in range(len(df.columns)):
    if df.dtypes[i]=="dtype('int32')":
        df[df.columns[i]]=df[df.columns[i]].astype("float")
        df[df.columns[i]].dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for i in range(len(df.columns)):
#       2     if df.dtypes[i]=="dtype('int32')":
#       3         df[df.columns[i]]=df[df.columns[i]].astype("float")
#
# NameError: name 'df' is not defined

# %%
for i in range(len(df.columns)):
    if df.dtypes.iloc[i]=="float64":
        df[df.columns[i]]=df[df.columns[i]].astype("int")
    print(df[df.columns[i]].dtypes)
# Out:
# int32
# object
# bool
# int32
# object
# int32
# int32
# int32
# int32
# int32
# int32
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
df.drop(["avg_rating"],axis=1,inplace=True)
df
# Out:
#              id                                              title  is_paid  \
# 0          4715             Online Vegan Vegetarian Cooking School     True
# 1          1769         The Lean Startup Talk at Stanford E-Corner    False
# 2          5664  How To Become a Vegan, Vegetarian, or Flexitarian     True
# 3          7723                               How to Train a Puppy     True
# 4          8157                      Web Design from the Ground Up     True
# ...         ...                                                ...      ...
# 209729  4913954                Let's Speak Urdu - The Urdu Grammar     True
# 209730  4914146  CompTIA Linux+ (XKO-004/005 # 2 Practice Exam ...     True
# 209731  4914002  CISSP 4 full exams #1 : All CISSP domains - 12...     True
# 209732  4913934  JD Edwards EnterpriseOne Fixed Assets Accounti...     True
# 209733  4914054  CISSP 4 full exams #2 : All CISSP domains - 12...     True
#
# ...
