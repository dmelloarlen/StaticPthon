# %%
import pandas as pd
import numpy as np
# df=pd.read_csv("")

# %%
dict={
    'A':[1,2,3,4,5],
    'B':["Book1","Book2","Book3","Book4","Book5"]
}
df=pd.DataFrame(dict)
df
# Out:
#    A      B
# 0  1  Book1
# 1  2  Book2
# 2  3  Book3
# 3  4  Book4
# 4  5  Book5

# %%
df=pd.DataFrame({
    'x':np.random.randn(100),
    'y':np.random.randn(100)
})
df
# Out:
#            x         y
# 0   0.407849  1.006710
# 1   0.681993  0.624948
# 2  -1.147920  0.816186
# 3   0.231929  2.062104
# 4   2.840371  1.180369
# ..       ...       ...
# 95  0.355364 -1.941950
# 96 -0.535456 -0.347855
# 97  1.215285  1.096330
# 98 -0.211041 -0.326797
# 99 -0.765823  1.989835
#
# [100 rows x 2 columns]

# %%
arr1=np.array([1,2,3,4,5])
arr2=np.array([5,6,7,8,9,0])
arr3=np.concatenate((arr1,arr2))
arr3
# Out:
# array([1, 2, 3, 4, 5, 5, 6, 7, 8, 9, 0])

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# plt.bar(df['x'],df['y'])
# plt.scatter(df['x'],df['y'],alpha=0.5)
# plt.figure(figsize=(10,10))
# plt.xlabel('x-axis')
# plt.ylabel('y-axis')
# plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
import altair as alt

scatter_ploat=alt.Chart(df).mark_circle(size=60).encode(
    x='x',
    y='y',
    tooltip=['x','y']
).properties(
    title='Scatter Ploat'
).interactive()

scatter_ploat
# Out:
# alt.Chart(...)
